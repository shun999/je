# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\human1\OneDrive - 埼玉大学\デスクトップ\12.29\視線データ\3. iwasaki.csv")

# %%
df.head()
# Out:
#    device_time_stamp  system_time_stamp  pc_time_stamp    left_x    left_y  \
# 0         1951228742         1764822322     1764822322  0.212236  0.279812
# 1         1951237075         1764822322     1764822322  0.211685  0.298827
# 2         1951245409         1764822322     1764822322  0.209829  0.267461
# 3         1951253746         1764822322     1764822322  0.207908  0.280470
# 4         1951262079         1764822322     1764822322  0.210727  0.285116
#
#     right_x   right_y  left_pupil  right_pupil  left_validity  right_validity  \
# 0       NaN       NaN    3.059891          NaN              1               0
# 1       NaN       NaN    3.087128          NaN              1               0
# 2 -0.477943 -0.431029    3.068756     4.284470              1               1
# 3 -0.470536 -0.438533    3.069702     4.262314              1               1
# 4 -0.464571 -0.470815    3.089111     4.255966              1               1
#
#    blink Marker
# 0  False    NaN
# 1  False    NaN
# 2  False    NaN
# 3  False    NaN
# 4  False    NaN

# %%
# Marker列の値が存在するインデックスを取得
marker_indices = df[df['Marker'].notna()].index
print(f"Marker列に値が存在するインデックス数: {len(marker_indices)}")
print(f"インデックス: {marker_indices.tolist()}")
# Out:
# Marker列に値が存在するインデックス数: 12
# インデックス: [31817, 34996, 35717, 37274, 46824, 49577, 50352, 53437, 60855, 63113, 63707, 66031]

# %%
df.iloc[marker_indices]
# Out:
#        device_time_stamp  system_time_stamp  pc_time_stamp    left_x  \
# 31817         2221212525         1764822592     1764822592  0.504451
# 34996         2247963397         1764822619     1764822619       NaN
# 35717         2253988458         1764822625     1764822625       NaN
# 37274         2267180552         1764822638     1764822638       NaN
# 46824         2347399979         1764822718     1764822718       NaN
# 49577         2370834079         1764822742     1764822742  0.503455
# 50352         2377392625         1764822748     1764822748  0.826745
# 53437         2404251846         1764822775     1764822775  0.254087
# 60855         2466612210         1764822838     1764822838       NaN
# 63113         2485596025         1764822857     1764822857       NaN
# 63707         2490579520         1764822862     1764822862       NaN
# 66031         2510096827         1764822881     1764822881       NaN
#
#          left_y   right_x   right_y  left_pupil  right_pupil  left_validity  \
# 31817  0.267168       NaN       NaN    3.346085          NaN              1
# 34996       NaN       NaN       NaN         NaN          NaN              0
# 35717       NaN       NaN       NaN         NaN          NaN              0
# 37274       NaN       NaN       NaN         NaN          NaN              0
# 46824       NaN       NaN       NaN         NaN          NaN              0
# 49577  0.352349  0.496065  0.362350    3.769150     3.520264              1
# 50352  0.382429       NaN       NaN    3.781143          NaN              1
# 53437  0.609729  0.256768  0.639715    4.007172     3.712814              1
# 60855       NaN       NaN       NaN         NaN          NaN              0
# 63113       NaN       NaN       NaN         NaN          NaN              0
# 63707       NaN       NaN       NaN         NaN          NaN              0
# 66031       NaN       NaN       NaN         NaN          NaN              0
#
#        right_validity  blink Marker
# 31817               0  False     s1
# 34996               0  False     e1
# 35717               0  False     s2
# 37274               0  False     e2
# 46824               0  False     s3
# 49577               1  False     e3
# 50352               0  False     s4
# 53437               1  False     e4
# 60855               0  False     s5
# 63113               0  False     e5
# 63707               0  False     s6
# 66031               0  False     e6

# %%
# Marker列の値を確認
print("Marker列の値:")
print(df.loc[marker_indices, 'Marker'].tolist())
# Out:
# Marker列の値:
# ['s1', 'e1', 's2', 'e2', 's3', 'e3', 's4', 'e4', 's5', 'e5', 's6', 'e6']

# %%
# Marker列で"s"から"e"までのデータを抽出
# "s"で始まるマーカーのインデックスを取得
s_indices = df[df['Marker'].notna() & (df['Marker'].astype(str).str.startswith('s'))].index
# "e"で終わるマーカーのインデックスを取得
e_indices = df[df['Marker'].notna() & (df['Marker'].astype(str).str.endswith('e'))].index

print(f"'s'で始まるマーカーのインデックス: {s_indices.tolist()}")
print(f"'e'で終わるマーカーのインデックス: {e_indices.tolist()}")

# 最初の"s"から最後の"e"までのデータを抽出
if len(s_indices) > 0 and len(e_indices) > 0:
    start_idx = s_indices[0]
    end_idx = e_indices[-1]
    
    # データを抽出（end_idx+1で最後の"e"の行も含める）
    segment_df = df.iloc[start_idx:end_idx+1]
    
    # Excelファイルに出力
    excel_path = r"C:\Users\human1\OneDrive - 埼玉大学\デスクトップ\12.29\視線データ\1. kubota_s_to_e.xlsx"
    segment_df.to_excel(excel_path, sheet_name='s_to_e', index=False, engine='openpyxl')
    
    print(f"\n抽出したデータ: {len(segment_df)}行")
    print(f"開始インデックス: {start_idx}, 終了インデックス: {end_idx}")
    print(f"Excelファイルに出力完了: {excel_path}")
else:
    print("'s'で始まるマーカーまたは'e'で終わるマーカーが見つかりませんでした。")
# Out:
# 's'で始まるマーカーのインデックス: [31817, 35717, 46824, 50352, 60855, 63707]
# 'e'で終わるマーカーのインデックス: []
# 's'で始まるマーカーまたは'e'で終わるマーカーが見つかりませんでした。

# %%
# "s1"から"e1"、"s2"から"e2"のようにペアごとにデータを抽出してExcelの各シートに出力
marker_df = df.loc[marker_indices, 'Marker'].reset_index()
marker_df.columns = ['index', 'marker']

# Excelファイルのパスを指定
excel_path = r"C:\Users\human1\OneDrive - 埼玉大学\デスクトップ\12.29\視線データ\1. kubota_pairs.xlsx"

with pd.ExcelWriter(excel_path, engine='openpyxl') as writer:
    # s1-e1, s2-e2などのペアを抽出
    for i in range(1, 7):  # s1-e1からs6-e6まで
        s_marker = f's{i}'
        e_marker = f'e{i}'
        
        # sとeのインデックスを取得
        s_idx = marker_df[marker_df['marker'] == s_marker]['index'].values
        e_idx = marker_df[marker_df['marker'] == e_marker]['index'].values
        
        if len(s_idx) > 0 and len(e_idx) > 0:
            start_idx = s_idx[0]
            end_idx = e_idx[0]
            
            # データを抽出（end_idx+1でeの行も含める）
            segment_df = df.iloc[start_idx:end_idx+1]
            
            # シート名（Excelのシート名は31文字まで、一部の特殊文字は使用不可）
            sheet_name = f"{s_marker}_to_{e_marker}"
            segment_df.to_excel(writer, sheet_name=sheet_name, index=False)
            print(f"シート '{sheet_name}': {len(segment_df)}行を出力 (インデックス {start_idx} から {end_idx})")
        else:
            print(f"警告: {s_marker} または {e_marker} が見つかりませんでした")

print(f"\nExcelファイルに出力完了: {excel_path}")
# Out:
# シート 's1_to_e1': 3180行を出力 (インデックス 31817 から 34996)
# シート 's2_to_e2': 1558行を出力 (インデックス 35717 から 37274)
# シート 's3_to_e3': 2754行を出力 (インデックス 46824 から 49577)
# シート 's4_to_e4': 3086行を出力 (インデックス 50352 から 53437)
# シート 's5_to_e5': 2259行を出力 (インデックス 60855 から 63113)
# シート 's6_to_e6': 2325行を出力 (インデックス 63707 から 66031)
#
# Excelファイルに出力完了: C:\Users\human1\OneDrive - 埼玉大学\デスクトップ\12.29\視線データ\1. kubota_pairs.xlsx
