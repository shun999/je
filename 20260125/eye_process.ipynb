# 165995         3688847169         1768968253     1768968253  0.490582
# 165996         3688855502         1768968253     1768968253  0.500608
# 165997         3688863836         1768968253     1768968253  0.496944
# 165998         3688872169         1768968253     1768968253  0.496554
#
#           left_y   right_x   right_y  left_pupil  right_pupil  left_validity  \
# 165994  0.489460  0.466829  0.465038    3.502777     3.367706              1
# 165995  0.467686  0.469465  0.481469    3.467667     3.355637              1
# 165996  0.469613  0.479785  0.467779    3.478088     3.333603              1
# 165997  0.461921  0.476193  0.474742    3.455017     3.348190              1
# 165998  0.461628  0.471904  0.478386    3.459045     3.348694              1
#
#         right_validity  blink     Marker
# ...

# %%
i = 2
with pd.ExcelWriter(r"F:\Je respire\トレーニング後\統合データ\output.xlsx") as writer:
    df.iloc[13793:15876].to_excel(writer, sheet_name="1", index=False)
    df.iloc[15876:17560].to_excel(writer, sheet_name="2", index=False)
    df.iloc[17560:19033].to_excel(writer, sheet_name="3", index=False)
    df.iloc[19033:21021-i].to_excel(writer, sheet_name="4", index=False)
    df.iloc[21021-i:25158-i].to_excel(writer, sheet_name="5", index=False)
    df.iloc[25158-i:31118-i].to_excel(writer, sheet_name="6", index=False)
    df.iloc[31118-i:33662-i].to_excel(writer, sheet_name="7", index=False)
    df.iloc[33662-i:39251-i].to_excel(writer, sheet_name="8", index=False)
    df.iloc[39251-i:40271-i].to_excel(writer, sheet_name="9", index=False)
    df.iloc[40271-i:45007-i].to_excel(writer, sheet_name="10", index=False)
    df.iloc[45007-i:48002-i].to_excel(writer, sheet_name="11", index=False)
    df.iloc[48002-i:49979-i].to_excel(writer, sheet_name="12", index=False)
    df.iloc[49979-i:51336-i].to_excel(writer, sheet_name="13", index=False)
    df.iloc[51336-i:56909-i].to_excel(writer, sheet_name="14", index=False)
    df.iloc[56909-i:60388-i].to_excel(writer, sheet_name="15", index=False)
    df.iloc[60388-i:61759-i].to_excel(writer, sheet_name="16", index=False)
    df.iloc[61759-i:65330-i].to_excel(writer, sheet_name="17", index=False)
    df.iloc[65330-i:66767-i].to_excel(writer, sheet_name="18", index=False)
    df.iloc[66767-i:68708-i].to_excel(writer, sheet_name="19", index=False)
    df.iloc[68708-i:72286-i].to_excel(writer, sheet_name="20", index=False)
    df.iloc[72286-i:74255-i].to_excel(writer, sheet_name="21", index=False)
    df.iloc[74255-i:76822-i].to_excel(writer, sheet_name="22", index=False)
    df.iloc[76822-i:80151-i].to_excel(writer, sheet_name="23", index=False)
    df.iloc[80151-i:86816-i].to_excel(writer, sheet_name="24", index=False)
    df.iloc[86816-i:90320-i].to_excel(writer, sheet_name="25", index=False)
    df.iloc[90320-i:103628-i].to_excel(writer, sheet_name="26", index=False)
    df.iloc[103628-i:124832-i].to_excel(writer, sheet_name="27", index=False)
    df.iloc[124832-i:128998-i].to_excel(writer, sheet_name="28", index=False)
    df.iloc[128998-i:135775-i].to_excel(writer, sheet_name="29", index=False)
    df.iloc[135775-i:152551-i].to_excel(writer, sheet_name="30", index=False)
    df.iloc[152551-i:157970-i].to_excel(writer, sheet_name="31", index=False)
    df.iloc[157970-i:162000-i].to_excel(writer, sheet_name="32", index=False)
    df.iloc[162183-i:165996-i].to_excel(writer, sheet_name="33", index=False)
    df.iloc[165996-i:].to_excel(writer, sheet_name="34", index=False)
