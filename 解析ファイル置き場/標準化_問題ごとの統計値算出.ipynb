# %%
import pandas as pd

# %%
df1 = pd.read_excel("E:/Je respire/生体情報/4. 標準化/standardized_output.xlsx", sheet_name=None)
df2 = pd.read_excel("E:/Je respire/生体情報/4. 標準化/standardized_output2.xlsx", sheet_name=None)
df3 = pd.read_excel("E:/Je respire/生体情報/4. 標準化/standardized_output3.xlsx", sheet_name=None)
df4 = pd.read_excel("E:/Je respire/生体情報/4. 標準化/standardized_output4.xlsx", sheet_name=None)
df5 = pd.read_excel("E:/Je respire/生体情報/4. 標準化/standardized_output5.xlsx", sheet_name=None)
df6 = pd.read_excel("E:/Je respire/生体情報/4. 標準化/standardized_output6.xlsx", sheet_name=None)
df7 = pd.read_excel("E:/Je respire/生体情報/4. 標準化/standardized_output7.xlsx", sheet_name=None)
df8 = pd.read_excel("E:/Je respire/生体情報/4. 標準化/standardized_output8.xlsx", sheet_name=None)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 9
#       7 df7 = pd.read_excel("E:/Je respire/生体情報/4. 標準化/standardized_output7.xlsx", sheet_name=None)
#       8 df8 = pd.read_excel("E:/Je respire/生体情報/4. 標準化/standardized_output8.xlsx", sheet_name=None)
# ----> 9 df9 = pd.read_excel("E:/Je respire/生体情報/4. 標準化/standardized_output9.xlsx", sheet_name=None)
#      10 df10 = pd.read_excel("E:/Je respire/生体情報/4. 標準化/standardized_output10.xlsx", sheet_name=None)
#
# File c:\WorkSpace\Je respire\env\lib\site-packages\pandas\io\excel\_base.py:508, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
# ...

# %%
df9 = pd.read_excel("E:/Je respire/生体情報/4. 標準化/standardized_output9.xlsx", sheet_name=None)
df10 = pd.read_excel("E:/Je respire/生体情報/4. 標準化/standardized_output10.xlsx", sheet_name=None)

# %%
df2["Q1"]["CH1_std"]
# Out:
# 0      -0.211958
# 1      -0.211958
# 2      -0.211958
# 3      -0.211958
# 4      -0.211958
#           ...
# 4083         NaN
# 4084         NaN
# 4085         NaN
# 4086         NaN
# 4087         NaN
# Name: CH1_std, Length: 4088, dtype: float64

# %%
all_means = []

for i, dataset in enumerate([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10]):
    for sheet_name, df in dataset.items():
        means = {}
        columns = ["left_pupil_std", "right_pupil_std", 
            "CH1_std", "CH2_std", "CH3_std", "CH4_std", "CH5_std", "CH6_std", "CH7_std", "CH8_std", "CH9_std", "CH10_std", "CH11_std", "CH12_std", "CH13_std", "CH14_std", "CH15_std", "CH16_std", "CH17_std", "CH18_std", "CH19_std", "CH20_std", "CH21_std", "CH22_std",
            "CH1.1_std", "CH2.1_std", "CH3.1_std", "CH4.1_std", "CH5.1_std", "CH6.1_std", "CH7.1_std", "CH8.1_std", "CH9.1_std", "CH10.1_std", "CH11.1_std", "CH12.1_std", "CH13.1_std", "CH14.1_std", "CH15.1_std", "CH16.1_std", "CH17.1_std", "CH18.1_std", "CH19.1_std", "CH20.1_std", "CH21.1_std", "CH22.1_std",
            "CH1.2_std", "CH2.2_std", "CH3.2_std", "CH4.2_std", "CH5.2_std", "CH6.2_std", "CH7.2_std", "CH8.2_std", "CH9.2_std", "CH10.2_std", "CH11.2_std", "CH12.2_std", "CH13.2_std", "CH14.2_std", "CH15.2_std", "CH16.2_std", "CH17.2_std", "CH18.2_std", "CH19.2_std", "CH20.2_std", "CH21.2_std", "CH22.2_std",
            "Sensor-E:SC/GSR_std", "Sensor-G:BVP_std", "[G] BVP Amp._std", "[G] Heart Rate_std", "[G] HRV Amp._std", "[G] HRV-LF Power (0,04-0,16 Hz)_std", "[G] HRV-HF Power (0,16-0,4 Hz)_std", "[G] HRV-LF / HRV-HF _std"
            ]
        for col in columns:
            if col in df.columns:
                means[col] = df[col].mean()
            else:
                means[col] = None
        means["dataset_no"] = i + 2
        means["sheet_name"] = sheet_name
        all_means.append(means)

# すべての統計値を1つのDataFrameにまとめて保存
all_means_df = pd.DataFrame(all_means)
all_means_df.to_csv("all_means2.csv", index=False)
